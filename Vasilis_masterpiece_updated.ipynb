# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
date_str1 = input("Enter the first date (yyyy-mm-dd): ")
date_str2 = input("Enter the second date (yyyy-mm-dd): ")

date_format = "%Y-%m-%d"
date1 = datetime.strptime(date_str1, date_format)
date2 = datetime.strptime(date_str2, date_format)
days_difference = (date2 - date1).days
url = "https://meteostat.p.rapidapi.com/point/daily"

querystring = {"lat":"52.52","lon":"13.405","start":date_str1,"end":date_str2,"alt":"184"}

headers = {
	"X-RapidAPI-Key": "647624aa1dmsh656f4c5b5e614f8p10bc1djsn052c2e87053a",
	"X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

weather_data=[]
for i in range(days_difference): 
    weather_data.append([response.json()['data'][i]])

list = [item for sublist in weather_data for item in sublist]
df=pd.DataFrame(list)
df
# Out:
# Enter the first date (yyyy-mm-dd):  2023-11-09
# Enter the second date (yyyy-mm-dd):  2023-11-15
#          date  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# 0  2023-11-09   7.5   5.9   9.3   1.5  None  192.0  17.3  37.0  1005.4  None
# 1  2023-11-10   6.7   4.0   8.7   0.4  None  192.0  14.8  33.3  1000.4  None
# 2  2023-11-11   4.0   2.5   6.1   NaN  None  219.0  11.1  22.2  1002.6  None
# 3  2023-11-12   4.5   3.5   6.0   NaN  None  261.0  11.9  27.8  1007.5  None
# 4  2023-11-13   4.0   2.7   5.6   NaN  None  252.0  12.2  25.9  1010.7  None
# 5  2023-11-14   5.3   3.7   7.0   NaN  None  243.0  13.3  29.6  1013.6  None

# %%
import requests

url = "https://yelp-reviews.p.rapidapi.com/business-reviews"

querystring = {"business_id":"berlin-icebar-berlin","page":"1","sort":"HIGHEST_RATED","language":"en","num_pages":"1"}

headers = {
	"X-RapidAPI-Key": "647624aa1dmsh656f4c5b5e614f8p10bc1djsn052c2e87053a",
	"X-RapidAPI-Host": "yelp-reviews.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'OK', 'request_id': '80ab1abf-5ba2-4473-ab7d-80181be6a081', 'data': {'reviews': [{'review_id': 'ApEJEkiuRErJcyXFURp7ig', 'review_rating': 5, 'review_photos': ['https://s3-media0.fl.yelpcdn.com/bphoto/e4McTT15AHxFI_-B5V1Zpw/300s.jpg'], 'review_photo_count': 1, 'review_photos_link': 'https://www.yelp.com/biz_photos/berlin-icebar-berlin?userid=6Co9CcHi8a04cHBwAI7QmQ', 'review_is_updated': False, 'review_feedback_counts': {'useful': 0, 'funny': 0, 'cool': 0}, 'review_datetime_utc': '2023-07-25T00:00:00.000Z', 'review_text': "The ice bar Berlin has been my favorite stop on my vacation so far. The drinks are fantastic with very good prices, and Nora. The bartender was amazing. Lots of great spots for photos and a great atmosphere. It's a little cold though. #icebar #poppingbottlesintheicelikeablizzard", 'review_language': 'en', 'author_id': '6Co9CcHi8a04cHBwAI7QmQ', 'author_name': 'Eric A.', 'author_location': 'Rohnert Park, CA', 'author_link': 'https://www.yelp.com/user_details
# ...

# %%
df=response.json()
reviews=df['data']['reviews']
a=[]
for i in range(len(reviews)):
    list=[reviews[i]['review_rating'],reviews[i]['review_text'],pd.to_datetime(reviews[i]['review_datetime_utc']).strftime('%Y-%m-%d')]
    a.append(list)
print(a)
df1 = pd.DataFrame(a)
df1.columns=['Rating', 'Review Text', 'Date']
df1
# Out:
# [[5, "The ice bar Berlin has been my favorite stop on my vacation so far. The drinks are fantastic with very good prices, and Nora. The bartender was amazing. Lots of great spots for photos and a great atmosphere. It's a little cold though. #icebar #poppingbottlesintheicelikeablizzard", '2023-07-25'], [5, 'Unique experience to drink beer or liquor in an ice glass or ice shot glass. 3 drinks for $20 are not bad at all. Go early so they are not jam packed. Service is friendly. Get glove and hat to enjoy the experience. Try them out. Get one drink outside while waiting for your turn and 2 drinks inside the ice bar for 30 minutes. Music is loud but upbeat', '2023-07-12'], [5, 'Very good experience. The staff was very nice and accommodating. I had a good time with friends and it was very interesting. Definitely recommend!!', '2023-05-23'], [5, 'Everything about this place was top notch. \n\nTo start you got these cute passport books for 3 drinks and then you were able to get your first dr
# ...
